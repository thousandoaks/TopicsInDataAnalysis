# %% [markdown]
# # Monitoring Data Drift
#
# Over time, models can become less effective at predicting accurately due to changing trends in feature data. This phenomenon is known as *data drift*, and it's important to monitor your machine learning solution to detect it so you can retrain your models if necessary.
#
# In this lab, you'll configure data drift monitoring for datasets.

# %% [markdown]
# ## Install the DataDriftDetector module
#
# To define a data drift monitor, you'll need to ensure that you have the latest version of the Azure ML SDK installed, and install the **datadrift** module; so run the following cell to do that:

# %%
# !pip install --upgrade azureml-sdk[notebooks,automl,explain]
# !pip install --upgrade azureml-datadrift
# Restart the kernel after installation is complete!
# Out:
# Collecting azureml-sdk[automl,explain,notebooks]
#   Downloading azureml_sdk-1.39.0-py3-none-any.whl (4.5 kB)
# Collecting azureml-train-automl-client~=1.39.0
#   Downloading azureml_train_automl_client-1.39.0-py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 17.5 MB/s eta 0:00:01
# Collecting azureml-pipeline~=1.39.0
#   Downloading azureml_pipeline-1.39.0-py3-none-any.whl (3.7 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.39.0
#   Downloading azureml_dataset_runtime-1.39.0-py3-none-any.whl (3.5 kB)
# Collecting azureml-core~=1.39.0
#   Downloading azureml_core-1.39.0-py3-none-any.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 45.7 MB/s eta 0:00:01
# Collecting azureml-train-core~=1.39.0
#   Downloading azureml_train_core-1.39.0-py3-none-any.whl (8.6 MB)
#      |████████████████████████████████| 8.6 MB 40.5 MB/s eta 0:00:01
# Collecting azureml-train-automl~=1.39.0; extra == "automl"
#   Downloading azureml_train_automl-1.39.0-py3-none-any.whl (3.5 kB)
# Collecting azureml-explain-model~=1.39.0; extra == "explain"
#   Downloading azureml_explain_model-1.39.0-py3-none-any.whl (21 kB)
# Collecting azureml-contrib-notebook~=1.39.0; extra == "notebooks"
#   Downloading azureml_contrib_notebook-1.39.0-py3-none-any.whl (30 kB)
# Collecting azureml-widgets~=1.39.0; extra == "notebooks"
#   Downloading azureml_widgets-1.39.0-py3-none-any.whl (14.2 MB)
#      |████████████████████████████████| 14.2 MB 43.1 MB/s eta 0:00:01
# Collecting azureml-automl-core~=1.39.0
#   Downloading azureml_automl_core-1.39.0-py3-none-any.whl (228 kB)
#      |████████████████████████████████| 228 kB 63.4 MB/s eta 0:00:01
# Collecting azureml-telemetry~=1.39.0
#   Downloading azureml_telemetry-1.39.0-py3-none-any.whl (31 kB)
# Collecting azureml-pipeline-steps~=1.39.0
#   Downloading azureml_pipeline_steps-1.39.0-py3-none-any.whl (70 kB)
#      |████████████████████████████████| 70 kB 3.3 MB/s  eta 0:00:01
# Collecting azureml-pipeline-core~=1.39.0
#   Downloading azureml_pipeline_core-1.39.0-py3-none-any.whl (313 kB)
#      |████████████████████████████████| 313 kB 57.4 MB/s eta 0:00:01
# Collecting azureml-dataprep<2.28.0a,>=2.27.1a
#   Downloading azureml_dataprep-2.27.1-py3-none-any.whl (39.4 MB)
#      |████████████████████████████████| 39.4 MB 68 kB/s s eta 0:00:01
# Requirement already satisfied, skipping upgrade: pyarrow<4.0.0,>=0.17.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.39.0->azureml-sdk[automl,explain,notebooks]) (3.0.0)
# Requirement already satisfied, skipping upgrade: numpy!=1.19.3; sys_platform == "linux" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.39.0->azureml-sdk[automl,explain,notebooks]) (1.18.5)
# Requirement already satisfied, skipping upgrade: fusepy<4.0.0,>=3.0.1; extra == "fuse" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.39.0->azureml-sdk[automl,explain,notebooks]) (3.0.1)
# Requirement already satisfied, skipping upgrade: msrest<1.0.0,>=0.5.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (0.6.21)
# Collecting knack~=0.9.0
#   Downloading knack-0.9.0-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 3.2 MB/s  eta 0:00:01
# Requirement already satisfied, skipping upgrade: paramiko<3.0.0,>=2.0.8 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (2.9.2)
# Requirement already satisfied, skipping upgrade: azure-mgmt-containerregistry<9.0.0,>=8.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (8.2.0)
# Requirement already satisfied, skipping upgrade: backports.tempfile in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (1.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-keyvault<10.0.0,>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (9.3.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-storage<20.0.0,>=16.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (19.0.0)
# Requirement already satisfied, skipping upgrade: jsonpickle<3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (2.1.0)
# Requirement already satisfied, skipping upgrade: packaging<22.0,>=20.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (21.3)
# Requirement already satisfied, skipping upgrade: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<37.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (36.0.1)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.7.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (2.8.2)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (0.10.0)
# Requirement already satisfied, skipping upgrade: PyJWT<3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (2.3.0)
# Requirement already satisfied, skipping upgrade: contextlib2<22.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (21.6.0)
# Requirement already satisfied, skipping upgrade: msrestazure<=0.6.4,>=0.4.33 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (0.6.4)
# Requirement already satisfied, skipping upgrade: pytz in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (2021.3)
# Requirement already satisfied, skipping upgrade: msal<2.0.0,>=1.15.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (1.16.0)
# Requirement already satisfied, skipping upgrade: requests[socks]<3.0.0,>=2.19.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (2.27.1)
# Requirement already satisfied, skipping upgrade: SecretStorage<4.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (3.3.1)
# Requirement already satisfied, skipping upgrade: pkginfo in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (1.8.2)
# Requirement already satisfied, skipping upgrade: argcomplete<2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (1.12.3)
# Requirement already satisfied, skipping upgrade: azure-mgmt-resource<21.0.0,>=15.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (20.0.0)
# Requirement already satisfied, skipping upgrade: docker<6.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (5.0.3)
# Requirement already satisfied, skipping upgrade: azure-common<2.0.0,>=1.1.12 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (1.1.27)
# Requirement already satisfied, skipping upgrade: pyopenssl<22.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (21.0.0)
# Requirement already satisfied, skipping upgrade: adal<=1.2.7,>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (1.2.7)
# Requirement already satisfied, skipping upgrade: pathspec<1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (0.9.0)
# Requirement already satisfied, skipping upgrade: msal-extensions<0.4,>=0.3.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (0.3.1)
# Requirement already satisfied, skipping upgrade: azure-mgmt-authorization<1.0.0,>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (0.61.0)
# Requirement already satisfied, skipping upgrade: azure-core<1.22 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (1.21.1)
# Requirement already satisfied, skipping upgrade: humanfriendly<11.0,>=4.7 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (10.0)
# Requirement already satisfied, skipping upgrade: urllib3<=1.26.7,>=1.23 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (1.26.7)
# Requirement already satisfied, skipping upgrade: ndg-httpsclient<=0.5.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (0.5.1)
# Requirement already satisfied, skipping upgrade: azure-graphrbac<1.0.0,>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (0.61.1)
# Collecting azureml-train-restclients-hyperdrive~=1.39.0
#   Downloading azureml_train_restclients_hyperdrive-1.39.0-py3-none-any.whl (19 kB)
# Collecting azureml-automl-runtime~=1.39.0
#   Downloading azureml_automl_runtime-1.39.0-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 39.9 MB/s eta 0:00:01
# Collecting azureml-train-automl-runtime~=1.39.0
#   Downloading azureml_train_automl_runtime-1.39.0-py3-none-any.whl (287 kB)
#      |████████████████████████████████| 287 kB 50.6 MB/s eta 0:00:01
# Collecting azureml-interpret~=1.39.0
#   Downloading azureml_interpret-1.39.0-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 788 kB/s  eta 0:00:01
# Requirement already satisfied, skipping upgrade: nbconvert<6 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (5.6.1)
# Requirement already satisfied, skipping upgrade: jupyter-client<7 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (6.1.12)
# Requirement already satisfied, skipping upgrade: ipython in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (7.16.3)
# Requirement already satisfied, skipping upgrade: ipykernel in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (5.5.6)
# Requirement already satisfied, skipping upgrade: papermill<2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (1.2.1)
# Requirement already satisfied, skipping upgrade: ipywidgets>=7.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-widgets~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (7.6.5)
# Requirement already satisfied, skipping upgrade: azure-storage-blob>=12.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-widgets~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (12.9.0)
# Requirement already satisfied, skipping upgrade: applicationinsights in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-telemetry~=1.39.0->azureml-train-automl-client~=1.39.0->azureml-sdk[automl,explain,notebooks]) (0.11.10)
# Requirement already satisfied, skipping upgrade: cloudpickle<3.0.0,>=1.1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.28.0a,>=2.27.1a->azureml-dataset-runtime[fuse]~=1.39.0->azureml-sdk[automl,explain,notebooks]) (2.0.0)
# Requirement already satisfied, skipping upgrade: dotnetcore2<3.0.0,>=2.1.14 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.28.0a,>=2.27.1a->azureml-dataset-runtime[fuse]~=1.39.0->azureml-sdk[automl,explain,notebooks]) (2.1.22)
# Requirement already satisfied, skipping upgrade: azure-identity==1.7.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.28.0a,>=2.27.1a->azureml-dataset-runtime[fuse]~=1.39.0->azureml-sdk[automl,explain,notebooks]) (1.7.0)
# Collecting azureml-dataprep-rslex~=2.3.0dev0
#   Downloading azureml_dataprep_rslex-2.3.1-cp36-cp36m-manylinux1_x86_64.whl (13.6 MB)
#      |████████████████████████████████| 13.6 MB 41.9 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: azureml-dataprep-native<39.0.0,>=38.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.28.0a,>=2.27.1a->azureml-dataset-runtime[fuse]~=1.39.0->azureml-sdk[automl,explain,notebooks]) (38.0.0)
# Requirement already satisfied, skipping upgrade: isodate>=0.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (0.6.1)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (1.3.0)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (2021.10.8)
# Requirement already satisfied, skipping upgrade: pyyaml in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from knack~=0.9.0->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (6.0)
# Requirement already satisfied, skipping upgrade: tabulate in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from knack~=0.9.0->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (0.8.9)
# Requirement already satisfied, skipping upgrade: pygments in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from knack~=0.9.0->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (2.11.2)
# Requirement already satisfied, skipping upgrade: pynacl>=1.0.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from paramiko<3.0.0,>=2.0.8->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (1.5.0)
# Requirement already satisfied, skipping upgrade: bcrypt>=3.1.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from paramiko<3.0.0,>=2.0.8->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (3.2.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-core<2.0.0,>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-mgmt-containerregistry<9.0.0,>=8.2.0->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (1.3.0)
# Requirement already satisfied, skipping upgrade: backports.weakref in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from backports.tempfile->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (1.0.post1)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonpickle<3.0.0->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (4.8.3)
# Requirement already satisfied, skipping upgrade: pyparsing!=3.0.5,>=2.0.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from packaging<22.0,>=20.0->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (3.0.6)
# Requirement already satisfied, skipping upgrade: cffi>=1.12 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<37.0.0->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (1.15.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from python-dateutil<3.0.0,>=2.7.3->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (1.16.0)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5; python_version >= "3" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (3.3)
# Requirement already satisfied, skipping upgrade: charset-normalizer~=2.0.0; python_version >= "3" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (2.0.10)
# Requirement already satisfied, skipping upgrade: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (1.7.1)
# Requirement already satisfied, skipping upgrade: jeepney>=0.6 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from SecretStorage<4.0.0->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (0.7.1)
# Requirement already satisfied, skipping upgrade: websocket-client>=0.32.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from docker<6.0.0->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (1.2.3)
# Requirement already satisfied, skipping upgrade: portalocker<3,>=1.0; python_version >= "3.5" and platform_system != "Windows" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msal-extensions<0.4,>=0.3.0->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (2.3.2)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ndg-httpsclient<=0.5.1->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (0.4.8)
# Requirement already satisfied, skipping upgrade: dataclasses<=0.8,>=0.6 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.6)
# Requirement already satisfied, skipping upgrade: boto3<=1.20.19 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.20.19)
# Collecting pmdarima==1.7.1
#   Downloading pmdarima-1.7.1-cp36-cp36m-manylinux1_x86_64.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 30.6 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: dill<0.4.0,>=0.2.8 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.3.4)
# Requirement already satisfied, skipping upgrade: smart-open<=1.9.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.9.0)
# Requirement already satisfied, skipping upgrade: onnxruntime<1.9.0,>=1.3.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.8.0)
# Requirement already satisfied, skipping upgrade: onnxmltools==1.4.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.4.1)
# Requirement already satisfied, skipping upgrade: keras2onnx<=1.6.0,>=1.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied, skipping upgrade: scikit-learn<0.23.0,>=0.19.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.22.2.post1)
# Collecting azureml-training-tabular~=1.39.0
#   Downloading azureml_training_tabular-1.39.0-py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 42.5 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: onnx<=1.7.0,>=1.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.7.0)
# Requirement already satisfied, skipping upgrade: onnxconverter-common<=1.6.0,>=1.4.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied, skipping upgrade: lightgbm<=3.2.1,>=2.0.11 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (2.3.0)
# Requirement already satisfied, skipping upgrade: botocore<=1.23.19 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.23.19)
# Requirement already satisfied, skipping upgrade: scipy<=1.5.2,>=1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.5.2)
# Requirement already satisfied, skipping upgrade: sklearn-pandas<=1.7.0,>=1.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.7.0)
# Requirement already satisfied, skipping upgrade: psutil<6.0.0,>=5.2.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (5.9.0)
# Requirement already satisfied, skipping upgrade: joblib==0.14.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.14.1)
# Requirement already satisfied, skipping upgrade: skl2onnx==1.4.9 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.4.9)
# Collecting pandas<=1.3.4,>=1.1.5
#   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 37.6 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: gensim<3.9.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (3.8.3)
# Collecting statsmodels<0.12,>=0.11.0
#   Downloading statsmodels-0.11.1-cp36-cp36m-manylinux1_x86_64.whl (8.7 MB)
#      |████████████████████████████████| 8.7 MB 55.3 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: nimbusml<=1.8.0,>=1.7.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.8.0)
# Requirement already satisfied, skipping upgrade: azure-storage-queue~=12.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (12.1.6)
# Collecting azureml-mlflow~=1.39.0
#   Downloading azureml_mlflow-1.39.0-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 1.6 MB/s  eta 0:00:01
# Requirement already satisfied, skipping upgrade: distributed<=2.30.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (2.30.1)
# Collecting azureml-defaults~=1.39.0
#   Downloading azureml_defaults-1.39.0-py3-none-any.whl (3.0 kB)
# Requirement already satisfied, skipping upgrade: markupsafe<2.1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (2.0.1)
# Requirement already satisfied, skipping upgrade: dask[complete]<=2.30.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (2.30.0)
# Requirement already satisfied, skipping upgrade: jinja2<=2.11.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (2.11.2)
# Requirement already satisfied, skipping upgrade: interpret-community==0.24.* in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-interpret~=1.39.0->azureml-explain-model~=1.39.0; extra == "explain"->azureml-sdk[automl,explain,notebooks]) (0.24.1)
# Requirement already satisfied, skipping upgrade: numba<0.54.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-interpret~=1.39.0->azureml-explain-model~=1.39.0; extra == "explain"->azureml-sdk[automl,explain,notebooks]) (0.53.1)
# Requirement already satisfied, skipping upgrade: shap<0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-interpret~=1.39.0->azureml-explain-model~=1.39.0; extra == "explain"->azureml-sdk[automl,explain,notebooks]) (0.39.0)
# Requirement already satisfied, skipping upgrade: mistune<2,>=0.8.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.8.4)
# Requirement already satisfied, skipping upgrade: defusedxml in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.7.1)
# Requirement already satisfied, skipping upgrade: entrypoints>=0.2.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.3)
# Requirement already satisfied, skipping upgrade: pandocfilters>=1.4.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (1.5.0)
# Requirement already satisfied, skipping upgrade: testpath in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.5.0)
# Requirement already satisfied, skipping upgrade: jupyter-core in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (4.9.1)
# Requirement already satisfied, skipping upgrade: bleach in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (4.1.0)
# Requirement already satisfied, skipping upgrade: traitlets>=4.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (4.3.3)
# Requirement already satisfied, skipping upgrade: nbformat>=4.4 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (5.1.3)
# Requirement already satisfied, skipping upgrade: tornado>=4.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jupyter-client<7->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (6.1)
# Requirement already satisfied, skipping upgrade: pyzmq>=13 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jupyter-client<7->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (22.3.0)
# Requirement already satisfied, skipping upgrade: pexpect; sys_platform != "win32" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (4.8.0)
# Collecting jedi<=0.17.2,>=0.10
#   Downloading jedi-0.17.2-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 49.5 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: pickleshare in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.7.5)
# Requirement already satisfied, skipping upgrade: backcall in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.2.0)
# Requirement already satisfied, skipping upgrade: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (3.0.24)
# Requirement already satisfied, skipping upgrade: setuptools>=18.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (50.3.0)
# Requirement already satisfied, skipping upgrade: decorator in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (5.1.1)
# Requirement already satisfied, skipping upgrade: ipython-genutils in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipykernel->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.2.0)
# Requirement already satisfied, skipping upgrade: future in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.18.2)
# Requirement already satisfied, skipping upgrade: click in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (8.0.3)
# Requirement already satisfied, skipping upgrade: ansiwrap in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.8.4)
# Requirement already satisfied, skipping upgrade: tqdm>=4.32.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (4.62.3)
# Requirement already satisfied, skipping upgrade: tenacity in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (8.0.1)
# Requirement already satisfied, skipping upgrade: widgetsnbextension~=3.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipywidgets>=7.0.0->azureml-widgets~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (3.5.2)
# Requirement already satisfied, skipping upgrade: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipywidgets>=7.0.0->azureml-widgets~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (1.0.2)
# Requirement already satisfied, skipping upgrade: distro>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from dotnetcore2<3.0.0,>=2.1.14->azureml-dataprep<2.28.0a,>=2.27.1a->azureml-dataset-runtime[fuse]~=1.39.0->azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests-oauthlib>=0.5.0->msrest<1.0.0,>=0.5.1->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (3.1.1)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonpickle<3.0.0->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (3.6.0)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.6.4; python_version < "3.8" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonpickle<3.0.0->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (4.0.1)
# Requirement already satisfied, skipping upgrade: pycparser in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cffi>=1.12->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<37.0.0->azureml-core~=1.39.0->azureml-sdk[automl,explain,notebooks]) (2.21)
# Requirement already satisfied, skipping upgrade: s3transfer<0.6.0,>=0.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from boto3<=1.20.19->azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.5.0)
# Collecting Cython<0.29.18,>=0.29
#   Downloading Cython-0.29.17-cp36-cp36m-manylinux1_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 49.2 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: boto>=2.32 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from smart-open<=1.9.0->azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (2.49.0)
# Requirement already satisfied, skipping upgrade: protobuf in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from onnxruntime<1.9.0,>=1.3.0->azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (3.19.3)
# Requirement already satisfied, skipping upgrade: flatbuffers in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from onnxruntime<1.9.0,>=1.3.0->azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (2.0)
# Requirement already satisfied, skipping upgrade: fire in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from keras2onnx<=1.6.0,>=1.4.0->azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.4.0)
# Requirement already satisfied, skipping upgrade: patsy>=0.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from statsmodels<0.12,>=0.11.0->azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.5.2)
# Requirement already satisfied, skipping upgrade: mlflow-skinny in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-mlflow~=1.39.0->azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.23.0)
# Requirement already satisfied, skipping upgrade: msgpack>=0.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from distributed<=2.30.1->azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.0.3)
# Requirement already satisfied, skipping upgrade: toolz>=0.8.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from distributed<=2.30.1->azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.11.2)
# Requirement already satisfied, skipping upgrade: sortedcontainers!=2.0.0,!=2.0.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from distributed<=2.30.1->azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (2.4.0)
# Requirement already satisfied, skipping upgrade: zict>=0.1.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from distributed<=2.30.1->azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (2.0.0)
# Requirement already satisfied, skipping upgrade: contextvars; python_version < "3.7" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from distributed<=2.30.1->azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (2.4)
# Requirement already satisfied, skipping upgrade: tblib>=1.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from distributed<=2.30.1->azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.7.0)
# Requirement already satisfied, skipping upgrade: azureml-inference-server-http~=0.4.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-defaults~=1.39.0->azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.4.2)
# Requirement already satisfied, skipping upgrade: configparser==3.7.4 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-defaults~=1.39.0->azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (3.7.4)
# Requirement already satisfied, skipping upgrade: json-logging-py==0.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-defaults~=1.39.0->azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.2)
# Requirement already satisfied, skipping upgrade: partd>=0.3.10; extra == "complete" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from dask[complete]<=2.30.0->azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.2.0)
# Requirement already satisfied, skipping upgrade: fsspec>=0.6.0; extra == "complete" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from dask[complete]<=2.30.0->azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (2022.1.0)
# Requirement already satisfied, skipping upgrade: bokeh!=2.0.0,>=1.0.0; extra == "complete" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from dask[complete]<=2.30.0->azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (2.3.3)
# Requirement already satisfied, skipping upgrade: ml-wrappers==0.0.6 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from interpret-community==0.24.*->azureml-interpret~=1.39.0->azureml-explain-model~=1.39.0; extra == "explain"->azureml-sdk[automl,explain,notebooks]) (0.0.6)
# Requirement already satisfied, skipping upgrade: interpret-core[required]<=0.2.7,>=0.1.20 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from interpret-community==0.24.*->azureml-interpret~=1.39.0->azureml-explain-model~=1.39.0; extra == "explain"->azureml-sdk[automl,explain,notebooks]) (0.2.7)
# Requirement already satisfied, skipping upgrade: llvmlite<0.37,>=0.36.0rc1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from numba<0.54.0->azureml-interpret~=1.39.0->azureml-explain-model~=1.39.0; extra == "explain"->azureml-sdk[automl,explain,notebooks]) (0.36.0)
# Requirement already satisfied, skipping upgrade: slicer==0.0.7 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from shap<0.40.0->azureml-interpret~=1.39.0->azureml-explain-model~=1.39.0; extra == "explain"->azureml-sdk[automl,explain,notebooks]) (0.0.7)
# Requirement already satisfied, skipping upgrade: webencodings in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from bleach->nbconvert<6->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.5.1)
# Requirement already satisfied, skipping upgrade: jsonschema!=2.5.0,>=2.4 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbformat>=4.4->nbconvert<6->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (3.2.0)
# Requirement already satisfied, skipping upgrade: ptyprocess>=0.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.7.0)
# Requirement already satisfied, skipping upgrade: parso<0.8.0,>=0.7.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jedi<=0.17.2,>=0.10->ipython->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.7.1)
# Requirement already satisfied, skipping upgrade: wcwidth in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.2.5)
# Requirement already satisfied, skipping upgrade: textwrap3>=0.9.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ansiwrap->papermill<2->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.9.2)
# Requirement already satisfied, skipping upgrade: notebook>=4.4.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (6.4.7)
# Requirement already satisfied, skipping upgrade: termcolor in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from fire->keras2onnx<=1.6.0,>=1.4.0->azureml-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.1.0)
# Requirement already satisfied, skipping upgrade: databricks-cli>=0.8.7 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from mlflow-skinny->azureml-mlflow~=1.39.0->azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.16.2)
# Requirement already satisfied, skipping upgrade: gitpython>=2.1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from mlflow-skinny->azureml-mlflow~=1.39.0->azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (3.1.18)
# Requirement already satisfied, skipping upgrade: heapdict in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from zict>=0.1.3->distributed<=2.30.1->azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.0.1)
# Requirement already satisfied, skipping upgrade: immutables>=0.9 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from contextvars; python_version < "3.7"->distributed<=2.30.1->azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.16)
# Requirement already satisfied, skipping upgrade: inference-schema==1.3.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-inference-server-http~=0.4.1->azureml-defaults~=1.39.0->azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.3.0)
# Requirement already satisfied, skipping upgrade: flask==1.0.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-inference-server-http~=0.4.1->azureml-defaults~=1.39.0->azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.0.3)
# Requirement already satisfied, skipping upgrade: gunicorn==20.1.0; platform_system != "Windows" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-inference-server-http~=0.4.1->azureml-defaults~=1.39.0->azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (20.1.0)
# Requirement already satisfied, skipping upgrade: locket in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from partd>=0.3.10; extra == "complete"->dask[complete]<=2.30.0->azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.2.1)
# Requirement already satisfied, skipping upgrade: pillow>=7.1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from bokeh!=2.0.0,>=1.0.0; extra == "complete"->dask[complete]<=2.30.0->azureml-train-automl-runtime~=1.39.0->azureml-train-automl~=1.39.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (8.0.0)
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert<6->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (21.4.0)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert<6->azureml-contrib-notebook~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.18.0)
# Requirement already satisfied, skipping upgrade: prometheus-client in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.12.0)
# Requirement already satisfied, skipping upgrade: Send2Trash>=1.8.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (1.8.0)
# Requirement already satisfied, skipping upgrade: argon2-cffi in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (21.3.0)
# Requirement already satisfied, skipping upgrade: nest-asyncio>=1.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets~=1.39.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (1.5.4)
# ...
# Requirement already satisfied, skipping upgrade: lightgbm in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-datadrift) (2.3.0)
# Requirement already satisfied, skipping upgrade: azureml-telemetry~=1.39.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-datadrift) (1.39.0)
# Requirement already satisfied, skipping upgrade: msrest>=0.5.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-datadrift) (0.6.21)
# Requirement already satisfied, skipping upgrade: numpy in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-datadrift) (1.18.5)
# Requirement already satisfied, skipping upgrade: scipy>=1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-datadrift) (1.5.2)
# Requirement already satisfied, skipping upgrade: azureml-pipeline-core~=1.39.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-datadrift) (1.39.0)
# Requirement already satisfied, skipping upgrade: pandas in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-datadrift) (1.1.5)
# Requirement already satisfied, skipping upgrade: scikit-learn in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-datadrift) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: jsonpickle in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-datadrift) (2.1.0)
# Requirement already satisfied, skipping upgrade: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<37.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (36.0.1)
# Requirement already satisfied, skipping upgrade: azure-mgmt-keyvault<10.0.0,>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (9.3.0)
# Requirement already satisfied, skipping upgrade: SecretStorage<4.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (3.3.1)
# Requirement already satisfied, skipping upgrade: contextlib2<22.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (21.6.0)
# Requirement already satisfied, skipping upgrade: humanfriendly<11.0,>=4.7 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (10.0)
# Requirement already satisfied, skipping upgrade: argcomplete<2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (1.12.3)
# Requirement already satisfied, skipping upgrade: packaging<22.0,>=20.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (21.3)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (0.10.0)
# Requirement already satisfied, skipping upgrade: msal-extensions<0.4,>=0.3.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (0.3.1)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.7.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (2.8.2)
# Requirement already satisfied, skipping upgrade: pathspec<1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (0.9.0)
# Requirement already satisfied, skipping upgrade: requests[socks]<3.0.0,>=2.19.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (2.27.1)
# Requirement already satisfied, skipping upgrade: PyJWT<3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (2.3.0)
# Requirement already satisfied, skipping upgrade: ndg-httpsclient<=0.5.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (0.5.1)
# Requirement already satisfied, skipping upgrade: azure-mgmt-resource<21.0.0,>=15.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (20.0.0)
# Requirement already satisfied, skipping upgrade: azure-graphrbac<1.0.0,>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (0.61.1)
# Requirement already satisfied, skipping upgrade: paramiko<3.0.0,>=2.0.8 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (2.9.2)
# Requirement already satisfied, skipping upgrade: msrestazure<=0.6.4,>=0.4.33 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (0.6.4)
# Requirement already satisfied, skipping upgrade: backports.tempfile in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (1.0)
# Requirement already satisfied, skipping upgrade: azure-core<1.22 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (1.21.1)
# Requirement already satisfied, skipping upgrade: knack~=0.9.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (0.9.0)
# Requirement already satisfied, skipping upgrade: urllib3<=1.26.7,>=1.23 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (1.26.7)
# Requirement already satisfied, skipping upgrade: docker<6.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (5.0.3)
# Requirement already satisfied, skipping upgrade: msal<2.0.0,>=1.15.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (1.16.0)
# Requirement already satisfied, skipping upgrade: pyopenssl<22.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (21.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-storage<20.0.0,>=16.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (19.0.0)
# Requirement already satisfied, skipping upgrade: pkginfo in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (1.8.2)
# Requirement already satisfied, skipping upgrade: azure-mgmt-authorization<1.0.0,>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (0.61.0)
# Requirement already satisfied, skipping upgrade: azure-common<2.0.0,>=1.1.12 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (1.1.27)
# Requirement already satisfied, skipping upgrade: azure-mgmt-containerregistry<9.0.0,>=8.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (8.2.0)
# Requirement already satisfied, skipping upgrade: pytz in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (2021.3)
# Requirement already satisfied, skipping upgrade: adal<=1.2.7,>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.39.0->azureml-datadrift) (1.2.7)
# Requirement already satisfied, skipping upgrade: pyarrow<4.0.0,>=0.17.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse,pandas]~=1.39.0->azureml-datadrift) (3.0.0)
# Requirement already satisfied, skipping upgrade: azureml-dataprep<2.28.0a,>=2.27.1a in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse,pandas]~=1.39.0->azureml-datadrift) (2.27.1)
# Requirement already satisfied, skipping upgrade: fusepy<4.0.0,>=3.0.1; extra == "fuse" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse,pandas]~=1.39.0->azureml-datadrift) (3.0.1)
# Requirement already satisfied, skipping upgrade: py4j==0.10.9.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pyspark->azureml-datadrift) (0.10.9.2)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from matplotlib<=3.2.1,>=3.0.2->azureml-datadrift) (3.0.6)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from matplotlib<=3.2.1,>=3.0.2->azureml-datadrift) (1.3.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from matplotlib<=3.2.1,>=3.0.2->azureml-datadrift) (0.11.0)
# Requirement already satisfied, skipping upgrade: applicationinsights in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-telemetry~=1.39.0->azureml-datadrift) (0.11.10)
# Requirement already satisfied, skipping upgrade: isodate>=0.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-datadrift) (0.6.1)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-datadrift) (2021.10.8)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-datadrift) (1.3.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from scikit-learn->azureml-datadrift) (0.14.1)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonpickle->azureml-datadrift) (4.8.3)
# Requirement already satisfied, skipping upgrade: cffi>=1.12 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<37.0.0->azureml-core~=1.39.0->azureml-datadrift) (1.15.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-core<2.0.0,>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-mgmt-keyvault<10.0.0,>=0.40.0->azureml-core~=1.39.0->azureml-datadrift) (1.3.0)
# Requirement already satisfied, skipping upgrade: jeepney>=0.6 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from SecretStorage<4.0.0->azureml-core~=1.39.0->azureml-datadrift) (0.7.1)
# Requirement already satisfied, skipping upgrade: portalocker<3,>=1.0; python_version >= "3.5" and platform_system != "Windows" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msal-extensions<0.4,>=0.3.0->azureml-core~=1.39.0->azureml-datadrift) (2.3.2)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from python-dateutil<3.0.0,>=2.7.3->azureml-core~=1.39.0->azureml-datadrift) (1.16.0)
# Requirement already satisfied, skipping upgrade: charset-normalizer~=2.0.0; python_version >= "3" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.39.0->azureml-datadrift) (2.0.10)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5; python_version >= "3" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.39.0->azureml-datadrift) (3.3)
# Requirement already satisfied, skipping upgrade: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.39.0->azureml-datadrift) (1.7.1)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ndg-httpsclient<=0.5.1->azureml-core~=1.39.0->azureml-datadrift) (0.4.8)
# Requirement already satisfied, skipping upgrade: bcrypt>=3.1.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from paramiko<3.0.0,>=2.0.8->azureml-core~=1.39.0->azureml-datadrift) (3.2.0)
# Requirement already satisfied, skipping upgrade: pynacl>=1.0.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from paramiko<3.0.0,>=2.0.8->azureml-core~=1.39.0->azureml-datadrift) (1.5.0)
# Requirement already satisfied, skipping upgrade: backports.weakref in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from backports.tempfile->azureml-core~=1.39.0->azureml-datadrift) (1.0.post1)
# Requirement already satisfied, skipping upgrade: pygments in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from knack~=0.9.0->azureml-core~=1.39.0->azureml-datadrift) (2.11.2)
# Requirement already satisfied, skipping upgrade: pyyaml in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from knack~=0.9.0->azureml-core~=1.39.0->azureml-datadrift) (6.0)
# Requirement already satisfied, skipping upgrade: tabulate in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from knack~=0.9.0->azureml-core~=1.39.0->azureml-datadrift) (0.8.9)
# Requirement already satisfied, skipping upgrade: websocket-client>=0.32.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from docker<6.0.0->azureml-core~=1.39.0->azureml-datadrift) (1.2.3)
# Requirement already satisfied, skipping upgrade: dotnetcore2<3.0.0,>=2.1.14 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.28.0a,>=2.27.1a->azureml-dataset-runtime[fuse,pandas]~=1.39.0->azureml-datadrift) (2.1.22)
# Requirement already satisfied, skipping upgrade: azure-identity==1.7.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.28.0a,>=2.27.1a->azureml-dataset-runtime[fuse,pandas]~=1.39.0->azureml-datadrift) (1.7.0)
# Requirement already satisfied, skipping upgrade: cloudpickle<3.0.0,>=1.1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.28.0a,>=2.27.1a->azureml-dataset-runtime[fuse,pandas]~=1.39.0->azureml-datadrift) (2.0.0)
# Requirement already satisfied, skipping upgrade: azureml-dataprep-rslex~=2.3.0dev0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.28.0a,>=2.27.1a->azureml-dataset-runtime[fuse,pandas]~=1.39.0->azureml-datadrift) (2.3.1)
# Requirement already satisfied, skipping upgrade: azureml-dataprep-native<39.0.0,>=38.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.28.0a,>=2.27.1a->azureml-dataset-runtime[fuse,pandas]~=1.39.0->azureml-datadrift) (38.0.0)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-datadrift) (3.1.1)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonpickle->azureml-datadrift) (3.6.0)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.6.4; python_version < "3.8" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonpickle->azureml-datadrift) (4.0.1)
# Requirement already satisfied, skipping upgrade: pycparser in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cffi>=1.12->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<37.0.0->azureml-core~=1.39.0->azureml-datadrift) (2.21)
# Requirement already satisfied, skipping upgrade: distro>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from dotnetcore2<3.0.0,>=2.1.14->azureml-dataprep<2.28.0a,>=2.27.1a->azureml-dataset-runtime[fuse,pandas]~=1.39.0->azureml-datadrift) (1.6.0)
# Installing collected packages: azureml-datadrift
#   Attempting uninstall: azureml-datadrift
#     Found existing installation: azureml-datadrift 1.38.0
#     Uninstalling azureml-datadrift-1.38.0:
#       Successfully uninstalled azureml-datadrift-1.38.0
# Successfully installed azureml-datadrift-1.39.0

# %% [markdown]
# > **Important**: Now you'll need to <u>restart the kernel</u>. In Jupyter, on the **Kernel** menu, select **Restart and Clear Output**. Then, when the output from the cell above has been removed and the kernel is restarted, continue the steps below.
#
# ## Connect to Your Workspace
#
# Now you're ready to connect to your workspace using the Azure ML SDK.
#
# > **Note**: If the authenticated session with your Azure subscription has expired since you completed the previous exercise, you'll be prompted to reauthenticate.

# %%
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to work with', ws.name)
# Out:
# Ready to work with session21workspace

# %% [markdown]
# ## Create a Baseline Dataset
#
# To monitor a dataset for data drift, you must register a *baseline* dataset (usually the dataset used to train your model) to use as a point of comparison with data collected in the future.

# %%
from azureml.core import Datastore, Dataset


# Upload the baseline data
default_ds = ws.get_default_datastore()

# %%
import pandas as pd

# %%
## we dowload some files from the internet
diabetes1 = pd.read_csv('https://raw.githubusercontent.com/MicrosoftLearning/mslearn-dp100/main/data/diabetes.csv')
diabetes2 = pd.read_csv('https://raw.githubusercontent.com/MicrosoftLearning/mslearn-dp100/main/data/diabetes2.csv')

# %%
## we create a dir
os.mkdir('./data2')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-15-e0ee8138ca80> in <module>
#       1 ## we create a dir
# ----> 2 os.mkdir('./data2')
#
# FileExistsError: [Errno 17] File exists: './data2'

# %%
## we store the files locally


diabetes1.to_csv('./data2/diabetes1.csv')
diabetes2.to_csv('./data2/diabetes2.csv')

# %%
default_ds.upload_files(files=['./data2/diabetes1.csv', './data2/diabetes2.csv'],
                       target_path='diabetes-baseline',
                       overwrite=True, 
                       show_progress=True)

# Create and register the baseline dataset
print('Registering baseline dataset...')
baseline_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, 'diabetes-baseline/*.csv'))
baseline_data_set = baseline_data_set.register(workspace=ws, 
                           name='diabetes baseline',
                           description='diabetes baseline data',
                           tags = {'format':'CSV'},
                           create_new_version=True)

print('Baseline dataset registered!')
# Out:
# Uploading an estimated of 2 files
# Uploading ./data2/diabetes1.csv
# Uploaded ./data2/diabetes1.csv, 1 files out of an estimated total of 2
# Uploading ./data2/diabetes2.csv
# Uploaded ./data2/diabetes2.csv, 2 files out of an estimated total of 2
# Uploaded 2 files
# Registering baseline dataset...
# Baseline dataset registered!

# %% [markdown]
# ## Create a Target Dataset
#
# Over time, you can collect new data with the same features as your baseline training data. To compare this new data to the baseline data, you must define a target dataset that includes the features you want to analyze for data drift as well as a timestamp field that indicates the point in time when the new data was current -this enables you to measure data drift over temporal intervals. The timestamp can either be a field in the dataset itself, or derived from the folder and filename pattern used to store the data. For example, you might store new data in a folder hierarchy that consists of a folder for the year, containing a folder for the month, which in turn contains a folder for the day; or you might just encode the year, month, and day in the file name like this: *data_2020-01-29.csv*; which is the approach taken in the following code:

# %%
import datetime as dt
import pandas as pd

print('Generating simulated data...')

# Load the smaller of the two data files
data = pd.read_csv('data2/diabetes2.csv')

# We'll generate data for the past 6 weeks
weeknos = reversed(range(6))

file_paths = []
for weekno in weeknos:
    
    # Get the date X weeks ago
    data_date = dt.date.today() - dt.timedelta(weeks=weekno)
    
    # Modify data to ceate some drift
    data['Pregnancies'] = data['Pregnancies'] + 1
    data['Age'] = round(data['Age'] * 1.2).astype(int)
    data['BMI'] = data['BMI'] * 1.1
    
    # Save the file with the date encoded in the filename
    file_path = 'data/diabetes_{}.csv'.format(data_date.strftime("%Y-%m-%d"))
    data.to_csv(file_path)
    file_paths.append(file_path)

# Upload the files
path_on_datastore = 'diabetes-target'
default_ds.upload_files(files=file_paths,
                       target_path=path_on_datastore,
                       overwrite=True,
                       show_progress=True)

# Use the folder partition format to define a dataset with a 'date' timestamp column
partition_format = path_on_datastore + '/diabetes_{date:yyyy-MM-dd}.csv'
target_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, path_on_datastore + '/*.csv'),
                                                       partition_format=partition_format)

# Register the target dataset
print('Registering target dataset...')
target_data_set = target_data_set.with_timestamp_columns('date').register(workspace=ws,
                                                                          name='diabetes target',
                                                                          description='diabetes target data',
                                                                          tags = {'format':'CSV'},
                                                                          create_new_version=True)

print('Target dataset registered!')
# Out:
# Generating simulated data...
# Uploading an estimated of 6 files
# Uploading data/diabetes_2022-02-01.csv
# Uploaded data/diabetes_2022-02-01.csv, 1 files out of an estimated total of 6
# Uploading data/diabetes_2022-02-08.csv
# Uploaded data/diabetes_2022-02-08.csv, 2 files out of an estimated total of 6
# Uploading data/diabetes_2022-02-15.csv
# Uploaded data/diabetes_2022-02-15.csv, 3 files out of an estimated total of 6
# Uploading data/diabetes_2022-02-22.csv
# Uploaded data/diabetes_2022-02-22.csv, 4 files out of an estimated total of 6
# Uploading data/diabetes_2022-03-01.csv
# Uploaded data/diabetes_2022-03-01.csv, 5 files out of an estimated total of 6
# Uploading data/diabetes_2022-03-08.csv
# Uploaded data/diabetes_2022-03-08.csv, 6 files out of an estimated total of 6
# Uploaded 6 files
# Registering target dataset...
# Target dataset registered!

# %% [markdown]
# ## Create a Data Drift Monitor
#
# Now you're ready to create a data drift monitor for the diabetes data. The data drift monitor will run periodicaly or on-demand to compare the baseline dataset with the target dataset, to which new data will be added over time.
#
# ### Create a Compute Target
#
# To run the data drift monitor, you'll need a compute target. In this lab, you'll use the compute cluster you created previously (if it doesn't exist, it will be created).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "your-compute-cluster"

try:
    # Check for existing compute target
    training_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        training_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        training_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# InProgress.
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ### Define the Data Drift Monitor
#
# Now you're ready to use a **DataDriftDetector** class to define the data drift monitor for your data. You can specify the features you want to monitor for data drift, the name of the compute target to be used to run the monitoring process, the frequency at which the data should be compared, the data drift threshold above which an alert should be triggered, and the latency (in hours) to allow for data collection.

# %%
from azureml.datadrift import DataDriftDetector

# set up feature list
features = ['Pregnancies', 'Age', 'BMI']

# set up data drift detector
monitor = DataDriftDetector.create_from_datasets(ws, 'diabetes-drift-detector', baseline_data_set, target_data_set,
                                                      compute_target=cluster_name, 
                                                      frequency='Week', 
                                                      feature_list=features, 
                                                      drift_threshold=.3, 
                                                      latency=24)
monitor
# Out:
# {'_logger': <_TelemetryLoggerContextAdapter azureml.datadrift._logging._telemetry_logger.azureml.datadrift.datadriftdetector (DEBUG)>, '_workspace': Workspace.create(name='session21workspace', subscription_id='17ed2092-9d59-4bde-be0e-18e04a8ef316', resource_group='session21resourcegroup'), '_frequency': 'Week', '_schedule_start': None, '_schedule_id': None, '_interval': 1, '_state': 'Disabled', '_alert_config': None, '_type': 'DatasetBased', '_id': '9b18fbcd-26cc-49d8-b4c1-44ec9544d80d', '_compute_target_name': 'your-compute-cluster', '_drift_threshold': 0.3, '_baseline_dataset_id': '741ce5d6-b1ef-4264-b48a-1a5fe9a6b801', '_target_dataset_id': 'b46e9d78-3a23-4947-bb90-816266db38c0', '_feature_list': ['Pregnancies', 'Age', 'BMI'], '_latency': 24, '_name': 'diabetes-drift-detector', '_latest_run_time': None, '_client': <azureml.datadrift._restclient.datadrift_client.DataDriftClient object at 0x7ff6802adc88>}

# %% [markdown]
# ## Backfill the Monitor
#
# You have a baseline dataset and a target dataset that includes simulated weekly data collection for six weeks. You can use this to backfill the monitor so that it can analyze data drift between the original baseline and the target data.
#
# > **Note** This may take some time to run, as the compute target must be started to run the backfill analysis. The widget may not always update to show the status, so click the link to observe the experiment status in Azure Machine Learning studio!

# %%
from azureml.widgets import RunDetails

backfill = monitor.backfill( dt.datetime.now() - dt.timedelta(weeks=6), dt.datetime.now())

RunDetails(backfill).show()
backfill.wait_for_completion()
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', '…

# %% [markdown]
# ## Analyze Data Drift
#
# You can use the following code to examine data drift for the points in time collected in the backfill run.

# %%
drift_metrics = backfill.get_metrics()
for metric in drift_metrics:
    print(metric, drift_metrics[metric])

# %% [markdown]
# You can also visualize the data drift metrics in [Azure Machine Learning studio](https://ml.azure.com) by following these steps:
#
# 1. On the **Datasets** page, view the **Dataset monitors** tab.
# 2. Click the data drift monitor you want to view.
# 3. Select the date range over which you want to view data drift metrics (if the column chart does not show multiple weeks of data, wait a minute or so and click **Refresh**).
# 4. Examine the charts in the **Drift overview** section at the top, which show overall drift magnitude and the drift contribution per feature.
# 5. Explore the charts in the **Feature detail** section at the bottom, which enable you to see various measures of drift for individual features.
#
# > **Note**: For help understanding the data drift metrics, see the [How to monitor datasets](https://docs.microsoft.com/azure/machine-learning/how-to-monitor-datasets#understanding-data-drift-results) in the Azure Machine Learning documentation.
#
# ## Explore Further
#
# This lab is designed to introduce you to the concepts and principles of data drift monitoring. To learn more about monitoring data drift using datasets, see the [Detect data drift on datasets](https://docs.microsoft.com/azure/machine-learning/how-to-monitor-datasets) in the Azure machine Learning documentation.
#
# You can also configure data drift monitoring for services deployed in an Azure Kubernetes Service (AKS) cluster. For more information about this, see [Detect data drift on models deployed to Azure Kubernetes Service (AKS)](https://docs.microsoft.com/azure/machine-learning/how-to-monitor-data-drift) in the Azure Machine Learning documentation.
