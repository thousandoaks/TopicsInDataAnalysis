# %%
# This will import the Twarc2 client and expansions class from twarc library and also the json library
from twarc import Twarc2, expansions
import json
import datetime

import pandas as pd

from twarc.expansions import ensure_flattened

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### 1. Let's open a connection to Twitter
# #### we use twarc library

# %%
## Agranda academic token
BearerToken='AAAAAAAAAAAAAAAAAAAAACH5XwEAAAAAa7SiHhh2e5UVvo3V3utnvHlYMR0%3D4glv0weeZtCeb9uynMIj138G7Ps0sbB6EHUNeIcXe8zSJz0VIb'

# %%
# This is where you initialize the client with your own bearer token (replace the XXXXX with your own bearer token)
client = Twarc2(bearer_token=BearerToken)

# %% [markdown]
# ### 2. Let's set the observation window

# %%
## Specify the end time in UTC for the time period you want Tweets from

end_time=datetime.datetime.now()-datetime.timedelta(minutes=20)

start_time=end_time-datetime.timedelta(days = 5)

# %%
start_time
# Out:
# datetime.datetime(2022, 1, 6, 14, 41, 16, 614701)

# %%
end_time
# Out:
# datetime.datetime(2022, 1, 11, 14, 41, 16, 614701)

# %% [markdown]
# ### 3. Let's set the query

# %%
# This is where we specify our query 
query = "(IEUniversity OR IEBusiness) "

# %% [markdown]
# ### 4. We compute the count of results
# #### It is always a good idea to know in advance how large the dataset is expected to be

# %%
count_results = client.counts_recent(query=query, granularity='day')

    # Twarc returns all Tweet counts for the criteria set above, so we page through the results
for page in count_results:
        print(json.dumps(page))
# Out:
# {"data": [{"end": "2022-01-05T00:00:00.000Z", "start": "2022-01-04T15:01:06.000Z", "tweet_count": 10}, {"end": "2022-01-06T00:00:00.000Z", "start": "2022-01-05T00:00:00.000Z", "tweet_count": 17}, {"end": "2022-01-07T00:00:00.000Z", "start": "2022-01-06T00:00:00.000Z", "tweet_count": 30}, {"end": "2022-01-08T00:00:00.000Z", "start": "2022-01-07T00:00:00.000Z", "tweet_count": 17}, {"end": "2022-01-09T00:00:00.000Z", "start": "2022-01-08T00:00:00.000Z", "tweet_count": 2}, {"end": "2022-01-10T00:00:00.000Z", "start": "2022-01-09T00:00:00.000Z", "tweet_count": 4}, {"end": "2022-01-11T00:00:00.000Z", "start": "2022-01-10T00:00:00.000Z", "tweet_count": 51}, {"end": "2022-01-11T15:01:06.000Z", "start": "2022-01-11T00:00:00.000Z", "tweet_count": 18}], "meta": {"total_tweet_count": 149}, "__twarc": {"url": "https://api.twitter.com/2/tweets/counts/recent?query=%28IEUniversity+OR+IEBusiness%29+&granularity=day", "version": "2.8.3", "retrieved_at": "2022-01-11T15:01:16+00:00"}}

# %% [markdown]
# ### 5. We execute the query
# #### in this case we use search_recent endpoint

# %%
search_results = client.search_recent(query=query,  max_results=100)

# %%
ListofTweets=[]
for page in search_results:
        # The Twitter API v2 returns the Tweet information and the user, media etc.  separately
        # so we use expansions.flatten to get all the information in a single JSON
        result = expansions.flatten(page)
        for tweet in result:
            # Here we are printing the full Tweet object JSON to the console
            
            ListofTweets.append(tweet)

# %%
type(ListofTweets)
# Out:
# list

# %%
type(ListofTweets[0])
# Out:
# dict

# %%
ListofTweets[0]
# Out:
# {'entities': {'annotations': [{'start': 27,
#     'end': 38,
#     'probability': 0.9943,
#     'type': 'Person',
#     'normalized_text': 'Manuel Muñiz'},
#    {'start': 183,
#     'end': 189,
#     'probability': 0.6935,
#     'type': 'Product',
#     'normalized_text': 'Twitter'}],
#   'mentions': [{'start': 41,
#     'end': 54,
#     'username': 'IEuniversity',
#     'id': '16825188',
#     'public_metrics': {'followers_count': 15667,
#      'following_count': 755,
#      'tweet_count': 7641,
#      'listed_count': 305},
#     'protected': False,
#     'url': 'http://t.co/g969sleuAc',
#     'description': 'Welcome to the official twitter account of IE University, Spain #IEUniversity  https://t.co/2MONGBLsBT',
#     'profile_image_url': 'https://pbs.twimg.com/profile_images/1407631330880405504/2gclPQfH_normal.jpg',
#     'location': 'Segovia, Spain',
#     'name': 'IE University',
#     'verified': True,
#     'entities': {'url': {'urls': [{'start': 0,
#         'end': 22,
#         'url': 'http://t.co/g969sleuAc',
#         'expanded_url': 'http://www.ie.edu/university/home',
#         'display_url': 'ie.edu/university/home'}]},
#      'description': {'urls': [{'start': 79,
#         'end': 102,
#         'url': 'https://t.co/2MONGBLsBT',
#         'expanded_url': 'http://goingtoieu.ie.edu/',
#         'display_url': 'goingtoieu.ie.edu'}],
#       'hashtags': [{'start': 64, 'end': 77, 'tag': 'IEUniversity'}]}},
#     'created_at': '2008-10-17T14:28:59.000Z'},
#    {'start': 241,
#     'end': 253,
#     'username': 'Haciendagob',
#     'id': '583744081',
#     'public_metrics': {'followers_count': 72091,
#      'following_count': 1178,
#      'tweet_count': 8891,
#      'listed_count': 1122},
#     'protected': False,
#     'url': 'https://t.co/Jf0YWpoLWk',
#     'description': 'Twitter oficial del Ministerio de Hacienda y Función Pública. Gobierno de España.  Madrid (Spain)',
#     'profile_image_url': 'https://pbs.twimg.com/profile_images/1414555238351187972/V5AwfApj_normal.jpg',
#     'location': 'Madrid, Comunidad de Madrid',
#     'name': 'Ministerio de Hacienda y Función Pública',
#     'verified': False,
#     'entities': {'url': {'urls': [{'start': 0,
#         'end': 23,
#         'url': 'https://t.co/Jf0YWpoLWk',
#         'expanded_url': 'http://www.hacienda.gob.es',
#         'display_url': 'hacienda.gob.es'}]}},
#     'created_at': '2012-05-18T12:03:33.000Z'}]},
#  'context_annotations': [{'domain': {'id': '46',
#     'name': 'Brand Category',
#     'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#    'entity': {'id': '781974596752842752', 'name': 'Services'}},
#   {'domain': {'id': '47',
#     'name': 'Brand',
#     'description': 'Brands and Companies'},
#    'entity': {'id': '10045225402', 'name': 'Twitter'}}],
#  'possibly_sensitive': False,
#  'reply_settings': 'everyone',
#  'public_metrics': {'retweet_count': 0,
#   'reply_count': 1,
#   'like_count': 0,
#   'quote_count': 0},
#  'text': 'Al hilo de lo expuesto por Manuel Muñiz (@IEuniversity), las tecnologías están planteando nuevos riesgos para nuestras democracias. Uno de ellos son las redes sociales (especialmente Twitter, que por cierto, figura como empresa morosa en la @Haciendagob). ▶️',
#  'author_id': '889892325924753408',
#  'source': 'Twitter Web App',
#  'created_at': '2022-01-11T15:09:59.000Z',
#  'lang': 'es',
#  'id': '1480919926558937093',
#  'conversation_id': '1480919926558937093',
#  'author': {'public_metrics': {'followers_count': 776,
#    'following_count': 991,
#    'tweet_count': 11190,
#    'listed_count': 2},
#   'protected': False,
#   'url': 'https://t.co/Ojhvk1DsJL',
#   'description': 'Investigadora: #whistleblower protect. Estrategias Anticorrupción y Políticas de Integridad. CRIMINÓLOGA. Consultant at @OCDE_fr\n\nDe la Palma, en Salamanca.',
#   'id': '889892325924753408',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/1475463530501619727/0Lm-AGDr_normal.jpg',
#   'location': 'Salamanca, España',
#   'username': 'CriFdezGl',
#   'name': 'Cris Fernández-González',
#   'verified': False,
#   'entities': {'url': {'urls': [{'start': 0,
#       'end': 23,
#       'url': 'https://t.co/Ojhvk1DsJL',
#       'expanded_url': 'https://www.linkedin.com/in/cristina-fernández-gonzález-5ab580109',
#       'display_url': 'linkedin.com/in/cristina-fe…'}]},
#    'description': {'hashtags': [{'start': 15,
#       'end': 29,
#       'tag': 'whistleblower'}],
#     'mentions': [{'start': 120, 'end': 128, 'username': 'OCDE_fr'}]}},
#   'pinned_tweet_id': '1477968149089853440',
#   'created_at': '2017-07-25T16:57:18.000Z'},
#  '__twarc': {'url': 'https://api.twitter.com/2/tweets/search/recent?expansions=author_id%2Cin_reply_to_user_id%2Creferenced_tweets.id%2Creferenced_tweets.id.author_id%2Centities.mentions.username%2Cattachments.poll_ids%2Cattachments.media_keys%2Cgeo.place_id&tweet.fields=attachments%2Cauthor_id%2Ccontext_annotations%2Cconversation_id%2Ccreated_at%2Centities%2Cgeo%2Cid%2Cin_reply_to_user_id%2Clang%2Cpublic_metrics%2Ctext%2Cpossibly_sensitive%2Creferenced_tweets%2Creply_settings%2Csource%2Cwithheld&user.fields=created_at%2Cdescription%2Centities%2Cid%2Clocation%2Cname%2Cpinned_tweet_id%2Cprofile_image_url%2Cprotected%2Cpublic_metrics%2Curl%2Cusername%2Cverified%2Cwithheld&media.fields=alt_text%2Cduration_ms%2Cheight%2Cmedia_key%2Cpreview_image_url%2Ctype%2Curl%2Cwidth%2Cpublic_metrics&poll.fields=duration_minutes%2Cend_datetime%2Cid%2Coptions%2Cvoting_status&place.fields=contained_within%2Ccountry%2Ccountry_code%2Cfull_name%2Cgeo%2Cid%2Cname%2Cplace_type&query=%28IEUniversity+OR+IEBusiness%29+&max_results=100',
#   'version': '2.8.3',
#   'retrieved_at': '2022-01-11T15:10:15+00:00'}}

# %% [markdown]
# ### 6. We store the result as a Pandas DataFrame

# %%
ListofTweetsDataFrame=pd.json_normalize(ListofTweets)

# %%
ListofTweetsDataFrame
# Out:
#                                                                                                                                                                                                                                                                                                                                  context_annotations  \
# 0    [{'domain': {'id': '46', 'name': 'Brand Category', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '781974596752842752', 'name': 'Services'}}, {'domain': {'id': '47', 'name': 'Brand', 'description': 'Brands and Companies'}, 'entity': {'id': '10045225402', 'name': 'Twitter'}}]
# 1                                                                                                                                                                                                                                                                                                                                                NaN
# 2                                                                                                                                                                                                                                                                                                                                                NaN
# 3                                                                                                                                                                                                                                                                                                                                                NaN
# 4                                                                                                                                                                                                                                                                                                                                                NaN
# ..                                                                                                                                                                                                                                                                                                                                               ...
# 145                                                                                                                                                                                                                                                                                                                                              NaN
# 146                                                                                                                                                                                                                                                                                                                                              NaN
# 147                                                                                                                                                                                                                                                                                                                                              NaN
# 148                                                                                                                                                                                                                                                                                                                                              NaN
# 149                                                                                                                                                                                                                                                                                                                                              NaN
#
#      possibly_sensitive reply_settings  \
# 0                 False       everyone
# 1                 False       everyone
# 2                 False       everyone
# 3                 False       everyone
# 4                 False       everyone
# ..                  ...            ...
# 145               False       everyone
# 146               False       everyone
# 147               False       everyone
# 148               False       everyone
# 149               False       everyone
#
#                                                                                                                                                                                                                                                                                                                  text  \
# 0                                                  Al hilo de lo expuesto por Manuel Muñiz (@IEuniversity), las tecnologías están planteando nuevos riesgos para nuestras democracias. Uno de ellos son las redes sociales (especialmente Twitter, que por cierto, figura como empresa morosa en la @Haciendagob). ▶️
# 1                                                                                                                                                                         RT @ACASspain: نظمت الملحقية زيارة أكاديمية لوفد طالبات الجامعات السعودية لجامعة @IEbusiness بمدريد التي تُعد من أفضل الجامعات العالمية في…
# 2    نظمت الملحقية زيارة أكاديمية لوفد طالبات الجامعات السعودية لجامعة @IEbusiness بمدريد التي تُعد من أفضل الجامعات العالمية في مجال إدارة الأعمال والتمويل ، واطلع الوفد على البرامج الأكاديمية وطرق التدريس والتدريب المتقدمة،وكذلك الخدمات المساندة والمرافق التعليمة والطلابية بالجامعة. https://t.co/tGG3F1spBj
# 3                                                                                                                                 @marmos2 @maria_patino @TheLuxonomist @AliciaDavara @MARIAGIRON @Venan_Salcines @Palomaa_ferrero @lolaripo @daretail @RetailerSpain @anadeluxes @IEbusiness https://t.co/a1hLhvq9lf
# 4              Carlos Núñez, nos cuenta los valores en los que se basa su marca @kontikiX, en la sesión informativa 'Emprendiendo con éxito en el sector del #lujo’ en el marco del Programa de Dirección y Gestión Estratégica del Universo del Lujo de @IEbusiness. https://t.co/FtrJIJn3Yf https://t.co/x0UUlnTyEy
# ..                                                                                                                                                                                                                                                                                                                ...
# 145                                                                                                                                                                                                                                                              @stereochromo @IEuniversity Asistiría de oyente ♥️👌🏻
# 146                                                                                                                                                                                                                                                     @stereochromo @IEuniversity Que guapo Wences! Mucha suerte!!!
# 147                                                                                                                                                                       RT @IeInsights: America against America is a (once obscure) book published in 1991 by Chinese academic Wáng Hùníng. Since the 2021 January…
# 148                                                                                                                                                                      RT @iefelix: The 6th of January is coming soon to mark the 1st anniversary of the assault on the #uscapitol , a black hole in American hist…
# 149                                                                                                                                                                      RT @IeInsights: As the digital age sees us increasingly access the world through the mirror of a screen, @ieuniversity professor Julián Mon…
#
#               author_id                  source                created_at  \
# 0    889892325924753408         Twitter Web App  2022-01-11T15:09:59.000Z
# 1             399747230      Twitter for iPhone  2022-01-11T14:08:28.000Z
# 2            2977820615      Twitter for iPhone  2022-01-11T13:45:08.000Z
# 3            3597062175         Twitter Web App  2022-01-11T12:57:24.000Z
# 4             273451954         Twitter Web App  2022-01-11T11:50:34.000Z
# ..                  ...                     ...                       ...
# 145            14147911      Twitter for iPhone  2022-01-04T15:50:09.000Z
# 146           116897975      Twitter for iPhone  2022-01-04T15:35:06.000Z
# 147            74139459      Twitter for iPhone  2022-01-04T15:32:47.000Z
# 148             6384782      Twitter for iPhone  2022-01-04T15:23:22.000Z
# 149  967503330066010112  Totally Real DH Person  2022-01-04T15:16:22.000Z
#
#     lang                   id      conversation_id  ...  \
# 0     es  1480919926558937093  1480919926558937093  ...
# 1     ar  1480904448050401283  1480904448050401283  ...
# 2     ar  1480898576167362560  1480898576167362560  ...
# 3    und  1480886559926853632  1480850792735285251  ...
# 4     es  1480869743179583489  1480869743179583489  ...
# ..   ...                  ...                  ...  ...
# 145   es  1478393321273933826  1478329962566459394  ...
# 146   es  1478389534861795335  1478329962566459394  ...
# 147   en  1478388950653980678  1478388950653980678  ...
# 148   en  1478386581908119552  1478386581908119552  ...
# 149   en  1478384817519665169  1478384817519665169  ...
#
#     in_reply_to_user.entities.description.cashtags      geo.place_id  \
# 0                                              NaN               NaN
# 1                                              NaN               NaN
# 2                                              NaN               NaN
# 3                                              NaN               NaN
# 4                                              NaN               NaN
# ..                                             ...               ...
# 145                                            NaN               NaN
# 146                                            NaN  206c436ce43a43a3
# 147                                            NaN               NaN
# 148                                            NaN               NaN
# 149                                            NaN               NaN
#
#      geo.place_type            geo.id  geo.country_code  geo.country  \
# 0               NaN               NaN               NaN          NaN
# 1               NaN               NaN               NaN          NaN
# 2               NaN               NaN               NaN          NaN
# 3               NaN               NaN               NaN          NaN
# 4               NaN               NaN               NaN          NaN
# ..              ...               ...               ...          ...
# 145             NaN               NaN               NaN          NaN
# 146            city  206c436ce43a43a3                ES        Spain
# 147             NaN               NaN               NaN          NaN
# 148             NaN               NaN               NaN          NaN
# 149             NaN               NaN               NaN          NaN
#
#      geo.geo.type                                      geo.geo.bbox  geo.name  \
# 0             NaN                                               NaN       NaN
# 1             NaN                                               NaN       NaN
# 2             NaN                                               NaN       NaN
# 3             NaN                                               NaN       NaN
# 4             NaN                                               NaN       NaN
# ..            ...                                               ...       ...
# 145           NaN                                               NaN       NaN
# 146       Feature  [-3.8890049, 40.3120713, -3.5180102, 40.6435181]    Madrid
# 147           NaN                                               NaN       NaN
# 148           NaN                                               NaN       NaN
# 149           NaN                                               NaN       NaN
#
#      geo.full_name
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 145            NaN
# 146  Madrid, Spain
# 147            NaN
# 148            NaN
# 149            NaN
#
# [150 rows x 73 columns]

# %%
ListofTweetsDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 73 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   context_annotations                              31 non-null     object
#  1   possibly_sensitive                               150 non-null    bool
#  2   reply_settings                                   150 non-null    object
#  3   text                                             150 non-null    object
#  4   author_id                                        150 non-null    object
#  5   source                                           150 non-null    object
#  6   created_at                                       150 non-null    object
#  7   lang                                             150 non-null    object
#  8   id                                               150 non-null    object
#  9   conversation_id                                  150 non-null    object
#  10  entities.annotations                             64 non-null     object
#  11  entities.mentions                                148 non-null    object
#  12  public_metrics.retweet_count                     150 non-null    int64
#  13  public_metrics.reply_count                       150 non-null    int64
#  14  public_metrics.like_count                        150 non-null    int64
#  15  public_metrics.quote_count                       150 non-null    int64
#  16  author.public_metrics.followers_count            150 non-null    int64
#  17  author.public_metrics.following_count            150 non-null    int64
#  18  author.public_metrics.tweet_count                150 non-null    int64
#  19  author.public_metrics.listed_count               150 non-null    int64
#  20  author.protected                                 150 non-null    bool
#  21  author.url                                       150 non-null    object
#  22  author.description                               150 non-null    object
#  23  author.id                                        150 non-null    object
#  24  author.profile_image_url                         150 non-null    object
#  25  author.location                                  102 non-null    object
#  26  author.username                                  150 non-null    object
#  27  author.name                                      150 non-null    object
#  28  author.verified                                  150 non-null    bool
#  29  author.entities.url.urls                         97 non-null     object
#  30  author.entities.description.hashtags             33 non-null     object
#  31  author.entities.description.mentions             55 non-null     object
#  32  author.pinned_tweet_id                           82 non-null     object
#  33  author.created_at                                150 non-null    object
#  34  __twarc.url                                      150 non-null    object
#  35  __twarc.version                                  150 non-null    object
#  36  __twarc.retrieved_at                             150 non-null    object
#  37  referenced_tweets                                105 non-null    object
#  38  attachments.media_keys                           31 non-null     object
#  39  attachments.media                                31 non-null     object
#  40  entities.urls                                    63 non-null     object
#  41  in_reply_to_user_id                              41 non-null     object
#  42  in_reply_to_user.public_metrics.followers_count  41 non-null     float64
#  43  in_reply_to_user.public_metrics.following_count  41 non-null     float64
#  44  in_reply_to_user.public_metrics.tweet_count      41 non-null     float64
#  45  in_reply_to_user.public_metrics.listed_count     41 non-null     float64
#  46  in_reply_to_user.protected                       41 non-null     object
#  47  in_reply_to_user.url                             41 non-null     object
#  48  in_reply_to_user.description                     41 non-null     object
#  49  in_reply_to_user.id                              41 non-null     object
#  50  in_reply_to_user.profile_image_url               41 non-null     object
#  51  in_reply_to_user.location                        26 non-null     object
#  52  in_reply_to_user.username                        41 non-null     object
#  53  in_reply_to_user.name                            41 non-null     object
#  54  in_reply_to_user.verified                        41 non-null     object
#  55  in_reply_to_user.entities.url.urls               21 non-null     object
#  56  in_reply_to_user.entities.description.urls       6 non-null      object
#  57  in_reply_to_user.entities.description.mentions   15 non-null     object
#  58  in_reply_to_user.pinned_tweet_id                 35 non-null     object
#  59  in_reply_to_user.created_at                      41 non-null     object
#  60  entities.hashtags                                40 non-null     object
#  61  author.entities.description.urls                 13 non-null     object
#  62  in_reply_to_user.entities.description.hashtags   6 non-null      object
#  63  in_reply_to_user.entities.description.cashtags   1 non-null      object
#  64  geo.place_id                                     4 non-null      object
#  65  geo.place_type                                   4 non-null      object
#  66  geo.id                                           4 non-null      object
#  67  geo.country_code                                 4 non-null      object
#  68  geo.country                                      4 non-null      object
#  69  geo.geo.type                                     4 non-null      object
#  70  geo.geo.bbox                                     4 non-null      object
#  71  geo.name                                         4 non-null      object
#  72  geo.full_name                                    4 non-null      object
# dtypes: bool(3), float64(4), int64(8), object(58)
# memory usage: 82.6+ KB

# %% [markdown]
# ### 7. We are ready to proceed with any analysis as required

# %% [markdown]
# #### 7.1. Find the top 20 influencers

# %%
ListofTweetsDataFrame[['id','author.name','text','public_metrics.retweet_count']].head(3)
# Out:
#                     id                              author.name  \
# 0  1480919926558937093                  Cris Fernández-González
# 1  1480904448050401283  أ.د.سعيد مسفرالمالكي Prof.Saeed Almalki
# 2  1480898576167362560    الملحقية الثقافية السعودية في إسبانيا
#
#                                                                                                                                                                                                                                                                                                                text  \
# 0                                                Al hilo de lo expuesto por Manuel Muñiz (@IEuniversity), las tecnologías están planteando nuevos riesgos para nuestras democracias. Uno de ellos son las redes sociales (especialmente Twitter, que por cierto, figura como empresa morosa en la @Haciendagob). ▶️
# 1                                                                                                                                                                       RT @ACASspain: نظمت الملحقية زيارة أكاديمية لوفد طالبات الجامعات السعودية لجامعة @IEbusiness بمدريد التي تُعد من أفضل الجامعات العالمية في…
# 2  نظمت الملحقية زيارة أكاديمية لوفد طالبات الجامعات السعودية لجامعة @IEbusiness بمدريد التي تُعد من أفضل الجامعات العالمية في مجال إدارة الأعمال والتمويل ، واطلع الوفد على البرامج الأكاديمية وطرق التدريس والتدريب المتقدمة،وكذلك الخدمات المساندة والمرافق التعليمة والطلابية بالجامعة. https://t.co/tGG3F1spBj
#
#    public_metrics.retweet_count
# 0                             0
# 1                             1
# 2                             1

# %%
Influencers=ListofTweetsDataFrame[['id','author.name','text','public_metrics.retweet_count']].groupby('author.name').sum()

# %%
Influencers.head(3)
# Out:
#                    public_metrics.retweet_count
# author.name
# Adriana Bonezzi                               0
# Alejandro Caínzos                            11
# Alex Roche                                    2

# %%
Influencers.sort_values(by='public_metrics.retweet_count',ascending=False).head(20)
# Out:
#                                         public_metrics.retweet_count
# author.name
# WS Atlantic/Pacific                                              149
# WorldSolutions light                                             149
# Manuel Muñiz                                                      20
# IE Center for the Governance of Change                            17
# 😍patri_glamour10                                                  12
# igorgaloanza                                                      11
# Susana del Río                                                    11
# Luz Rodriguez                                                     11
# Javier Ayuso Canals                                               11
# Ricardo López-Aranda                                              11
# Federico Steinberg                                                11
# Dany Bahar                                                        11
# Alejandro Caínzos                                                 11
# yolanda regodon                                                   11
# Arancha González                                                  11
# Project Syndicate                                                  6
# Görkem Akman                                                       6
# Dr. Mark Esposito                                                  6
# Manuel Butler                                                      6
# TheGreatFactbookOfLife                                             6

# %% [markdown]
# #### 7.2. Find the top 20 tweets

# %%
ListofTweetsDataFrame[['id','text','author.name','public_metrics.retweet_count']].sort_values(by='public_metrics.retweet_count',ascending=False).head(20)
# Out:
#                       id  \
# 76   1479596807038844928
# 106  1478933094472482821
# 133  1478707124263919621
# 49   1480545392123129862
# 48   1480547771979554817
# 28   1480615343865352198
# 21   1480651259300491265
# 45   1480564849239281664
# 46   1480564310539649026
# 47   1480554883484946432
# 24   1480633227656245250
# 51   1480537998194262018
# 53   1480536585544376330
# 54   1480536423333826563
# 55   1480535875733839877
# 50   1480538892537372674
# 52   1480537759542661120
# 36   1480591126667173892
# 35   1480591326022406147
# 5    1480866617579954179
#
#                                                                                                                                                                                                                                                                                          text  \
# 76                                                                                                                                              RT @WSlightly: @sylvango @mycircaa 👨‍💻https://t.co/dDCokx16ey\nZonePhysics Curbed ArchDigest jpmorgan macminltd CornishLithium argonne Oroco…
# 106                                                                                                                                             RT @WSlightly: @sylvango @mycircaa 👨‍💻https://t.co/dDCokx16ey\nZonePhysics Curbed ArchDigest jpmorgan macminltd CornishLithium argonne Oroco…
# 133                                                                                                                                              RT @edans: "El metaverso, los chips y el ‘ecommerce’ social ganarán protagonismo este año", artículo de @marimarjimenez en @CincoDiascom co…
# 49                                                                                                                                               RT @manuelmunizv: The colleagues at @ProSyn publish today this piece of mine titled “Technology and the Global Struggle for Democracy”. Wet…
# 48                                                                                                                                               RT @manuelmunizv: The colleagues at @ProSyn publish today this piece of mine titled “Technology and the Global Struggle for Democracy”. Wet…
# 28                                                                                                                                               RT @manuelmunizv: The colleagues at @ProSyn publish today this piece of mine titled “Technology and the Global Struggle for Democracy”. Wet…
# 21                                                                                                                                               RT @manuelmunizv: The colleagues at @ProSyn publish today this piece of mine titled “Technology and the Global Struggle for Democracy”. Wet…
# 45                                                                                                                                               RT @manuelmunizv: The colleagues at @ProSyn publish today this piece of mine titled “Technology and the Global Struggle for Democracy”. Wet…
# 46                                                                                                                                               RT @manuelmunizv: The colleagues at @ProSyn publish today this piece of mine titled “Technology and the Global Struggle for Democracy”. Wet…
# 47                                                                                                                                               RT @manuelmunizv: The colleagues at @ProSyn publish today this piece of mine titled “Technology and the Global Struggle for Democracy”. Wet…
# 24                                                                                                                                               RT @manuelmunizv: The colleagues at @ProSyn publish today this piece of mine titled “Technology and the Global Struggle for Democracy”. Wet…
# 51                                                                                                                                               RT @manuelmunizv: The colleagues at @ProSyn publish today this piece of mine titled “Technology and the Global Struggle for Democracy”. Wet…
# 53                                                                                                                                               RT @manuelmunizv: The colleagues at @ProSyn publish today this piece of mine titled “Technology and the Global Struggle for Democracy”. Wet…
# 54                                                                                                                                               RT @manuelmunizv: The colleagues at @ProSyn publish today this piece of mine titled “Technology and the Global Struggle for Democracy”. Wet…
# 55   The colleagues at @ProSyn publish today this piece of mine titled “Technology and the Global Struggle for Democracy”. Wether technology advances democratic values or not will be one of the big questions of our time: https://t.co/ozuRRaF1kh @IEuniversity @ieGovernance @ieGPAffairs
# 50                                                                                                                                               RT @ProSyn: It is a mistake to view the January 6, 2021, assault on the US Capitol as a uniquely American event, argues @manuelmunizv of @I…
# 52                                                                                                                                               RT @ProSyn: It is a mistake to view the January 6, 2021, assault on the US Capitol as a uniquely American event, argues @manuelmunizv of @I…
# 36                                                                                                                                               RT @ProSyn: It is a mistake to view the January 6, 2021, assault on the US Capitol as a uniquely American event, argues @manuelmunizv of @I…
# 35                                                                                                                                               RT @ProSyn: It is a mistake to view the January 6, 2021, assault on the US Capitol as a uniquely American event, argues @manuelmunizv of @I…
# 5                                                                                                                                                RT @ProSyn: It is a mistake to view the January 6, 2021, assault on the US Capitol as a uniquely American event, argues @manuelmunizv of @I…
#
#                                 author.name  public_metrics.retweet_count
# 76                      WS Atlantic/Pacific                           149
# 106                    WorldSolutions light                           149
# 133                        😍patri_glamour10                            12
# 49                           Susana del Río                            11
# 48                        Alejandro Caínzos                            11
# 28                      Javier Ayuso Canals                            11
# 21                         Arancha González                            11
# 45                       Federico Steinberg                            11
# 46                          yolanda regodon                            11
# 47                             igorgaloanza                            11
# 24                     Ricardo López-Aranda                            11
# 51                            Luz Rodriguez                            11
# 53                               Dany Bahar                            11
# 54   IE Center for the Governance of Change                            11
# 55                             Manuel Muñiz                            11
# 50                             Görkem Akman                             6
# 52                   TheGreatFactbookOfLife                             6
# 36                             Manuel Muñiz                             6
# 35   IE Center for the Governance of Change                             6
# 5                             Manuel Butler                             6
